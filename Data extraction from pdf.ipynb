# %% [markdown]
# The task here was to extract the table showing the number of people using desktop or laptop or tablet in Kirinyaga county from the KNBS 2019 census data which is in pdf format and export that to a csv file.

# %%
#import the libraries to use
# tabula should be installed first using pip install tabula-py. It is used to read PDF's

import pandas as pd
import tabula

# %%
# %%time
#read the data which is located in the default directory
# Ensure pages is specified to 'all' if you want to extract tables from all the pages, 
# or the exact page number you want to extract data from

df = tabula.read_pdf('census.pdf', pages='all')
# Out:
# Wall time: 2min 34s

# %%
#Extracting all the data results in a list of tables
df[1]
# Out:
#    COUNTY COUNTY NAME SUB-COUNTY SUB-COUNTY.1 COUNTY.1 COUNTY NAME.1  \
# 0    CODE         NaN       CODE         NAME     CODE           NaN
# 1       1     MOMBASA        101    CHANGAMWE       12          MERU
# 2       1     MOMBASA        102        JOMVU       12          MERU
# 3       1     MOMBASA        103      KISAUNI       12          MERU
# 4       1     MOMBASA        104       LIKONI       12          MERU
# ..    ...         ...        ...          ...      ...           ...
# 57     10    MARSABIT       1006   NORTH HORR       17       MAKUENI
# 58     10    MARSABIT       1007       SOLOLO       18     NYANDARUA
# 59     11      ISIOLO       1101   GARBATULLA       18     NYANDARUA
# 60     11      ISIOLO       1102       ISIOLO       18     NYANDARUA
# 61     11      ISIOLO       1103        MERTI       18     NYANDARUA
#
#    SUB-COUNTY.2     SUB-COUNTY.3
# 0          CODE             NAME
# 1          1201       BUURI EAST
# 2          1202       BUURI WEST
# 3          1203   IGEMBE CENTRAL
# 4          1204     IGEMBE NORTH
# ..          ...              ...
# 57         1709            NZAUI
# 58         1801         KINANGOP
# 59         1802  NYANDARUA SOUTH
# 60         1803        MIRANGINE
# 61         1804         KIPIPIRI
#
# [62 rows x 8 columns]

# %%
#Export all the tables to different csv files

j=0
while j < len(df):
    df[j].to_csv('output'+str(j)+'.csv', index=False) #sep=";")
    j += 1

# %%
#Calling the specific dataframe that has all the data we are looking for

df[426]
# Out:
#              County /   Population 3 Years and above Unnamed: 0 Unnamed: 1  \
# 0          Sub-County             Total* Male Female     Total*   per cent
# 1           KIRINYAGA        571,312 281,556 289,729    137,563       24.1
# 2   KIRINYAGA CENTRAL          114,807 55,919 58,884     32,210       28.1
# 3      KIRINYAGA EAST          127,964 63,267 64,689     28,245       22.1
# 4      KIRINYAGA WEST          107,763 52,630 55,129     26,981       25.0
# 5           MWEA EAST          122,344 60,740 61,598     30,098       24.6
# 6           MWEA WEST           98,400 48,976 49,419     20,009       20.3
# 7    MT. KENYA FOREST                       34 24 10         20       58.8
# 8            MURANG'A        988,224 488,689 499,505    204,760       20.7
# 9       MURANG'A EAST          101,606 49,826 51,779     27,922       27.5
# 10            KANGEMA           75,668 37,165 38,500     15,764       20.8
# 11           MATHIOYA           87,438 42,738 44,699     15,896       18.2
# 12             KAHURO           83,338 40,864 42,467     15,911       19.1
# 13     MURANG'A SOUTH          172,158 85,252 86,901     36,809       21.4
# 14            GATANGA          175,723 88,134 87,586     37,930       21.6
# 15             KIGUMO          128,481 63,728 64,750     23,144       18.0
# 16            KANDARA          163,770 80,952 82,811     31,359       19.1
# 17    ABERDARE FOREST                       42 30 12         25       59.5
# 18             KIAMBU  2,231,514 1,092,380 1,139,012    952,268       42.7
# 19      GATUNDU NORTH          102,915 50,634 52,279     22,795       22.1
# 20      GATUNDU SOUTH          114,575 56,630 57,941     26,346       23.0
# 21         GITHUNGURI          155,046 76,874 78,164     42,369       27.3
# 22               JUJA        277,171 136,491 140,658    133,777       48.3
# 23             KABETE          184,688 90,196 94,478     87,230       47.2
# 24            KIAMBAA        218,165 106,623 111,530    101,132       46.4
# 25             KIAMBU          133,949 63,471 70,464     67,815       50.6
# 26             KIKUYU          172,833 83,603 89,226     83,951       48.6
# 27               LARI          125,884 62,427 63,454     29,719       23.6
# 28             LIMURU          147,004 73,445 73,559     49,957       34.0
# 29              RUIRU        340,681 165,256 175,406    181,536       53.3
# 30         THIKA EAST           35,971 18,224 17,743     10,688       29.7
# 31         THIKA WEST        222,632 108,506 114,110    114,953       51.6
# 32            TURKANA        851,797 439,467 412,311     58,533        6.9
# 33             KIBISH           33,611 17,046 16,564        890        2.6
# 34              LOIMA           98,183 49,440 48,743      2,901        3.0
# 35    TURKANA CENTRAL          166,135 82,906 83,229     19,585       11.8
# 36       TURKANA EAST          130,834 72,914 57,908      7,414        5.7
# 37      TURKANA NORTH           59,378 29,770 29,608      2,038        3.4
# 38      TURKANA SOUTH          142,538 72,846 69,688      9,280        6.5
# 39       TURKANA WEST        221,118 114,545 106,571     16,425        7.4
#
#    Use of Internet Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0    Male per cent     Female   per cent     Total*
# 1      73,577 26.1     63,977       22.1     55,510
# 2      16,912 30.2     15,297       26.0     14,786
# 3      15,600 24.7     12,642       19.5     10,917
# 4      14,332 27.2     12,649       22.9     11,750
# 5      15,721 25.9     14,374       23.3     11,147
# 6      10,996 22.5      9,011       18.2      6,901
# 7          16 66.7          4       40.0          9
# 8     111,466 22.8     93,286       18.7     80,287
# 9      14,072 28.2     13,850       26.7     13,329
# 10      8,583 23.1      7,180       18.6      5,854
# 11      8,626 20.2      7,270       16.3      6,196
# 12      8,631 21.1      7,275       17.1      5,486
# 13     20,103 23.6     16,706       19.2     14,629
# 14     21,157 24.0     16,772       19.1     15,445
# 15     13,054 20.5     10,089       15.6      8,139
# 16     17,219 21.3     14,140       17.1     11,201
# 17         21 70.0          4       33.3          8
# 18    486,137 44.5    466,080       40.9    486,912
# 19     12,306 24.3     10,488       20.1      7,491
# 20     14,104 24.9     12,242       21.1      8,851
# 21     22,149 28.8     20,218       25.9     16,086
# 22     68,981 50.5     64,788       46.1     71,054
# 23     44,176 49.0     43,047       45.6     46,746
# 24     50,970 47.8     50,160       45.0     51,780
# 25     32,488 51.2     35,319       50.1     40,193
# 26     41,613 49.8     42,336       47.4     49,598
# 27     16,394 26.3     13,325       21.0     10,661
# 28     26,789 36.5     23,168       31.5     22,425
# 29     92,193 55.8     89,333       50.9     97,382
# 30      5,780 31.7      4,905       27.6      4,157
# 31     58,194 53.6     56,751       49.7     60,488
# 32      36,920 8.4     21,613        5.2     20,541
# 33         591 3.5        299        1.8        310
# 34       1,821 3.7      1,080        2.2      1,062
# 35     11,961 14.4      7,624        9.2      7,633
# 36       4,754 6.5      2,660        4.6      2,839
# 37       1,339 4.5        699        2.4        773
# 38       5,851 8.0      3,429        4.9      3,555
# 39      10,603 9.3      5,822        5.5      4,369
#
#    Use of Desktop Computer/Laptop/Tablet Unnamed: 5
# 0          per cent Male per cent Female   per cent
# 1                 9.7 30,794 10.9 24,715        8.5
# 2                  12.9 7,974 14.3 6,812       11.6
# 3                    8.5 6,183 9.8 4,734        7.3
# 4                  10.9 6,526 12.4 5,224        9.5
# 5                   9.1 6,141 10.1 5,005        8.1
# 6                    7.0 3,962 8.1 2,939        5.9
# 7                          26.5 8 33.3 1       10.0
# 8                  8.1 44,903 9.2 35,380        7.1
# 9                  13.1 6,933 13.9 6,396       12.4
# 10                   7.7 3,241 8.7 2,611        6.8
# 11                   7.1 3,442 8.1 2,754        6.2
# 12                   6.6 3,138 7.7 2,346        5.5
# 13                   8.5 8,285 9.7 6,344        7.3
# 14                   8.8 8,660 9.8 6,785        7.7
# 15                   6.3 4,779 7.5 3,360        5.2
# 16                   6.8 6,419 7.9 4,782        5.8
# 17                         19.0 6 20.0 2       16.7
# 18             21.8 261,359 23.9 225,529       19.8
# 19                   7.3 4,301 8.5 3,190        6.1
# 20                   7.7 4,901 8.7 3,950        6.8
# 21                 10.4 8,839 11.5 7,247        9.3
# 22               25.6 39,208 28.7 31,842       22.6
# 23               25.3 25,118 27.8 21,623       22.9
# 24               23.7 27,063 25.4 24,714       22.2
# 25               30.0 20,311 32.0 19,881       28.2
# 26               28.7 25,598 30.6 23,999       26.9
# 27                   8.5 5,999 9.6 4,662        7.3
# 28               15.3 12,384 16.9 10,041       13.7
# 29               28.6 52,725 31.9 44,652       25.5
# 30                 11.6 2,305 12.6 1,852       10.4
# 31               27.2 32,607 30.1 27,876       24.4
# 32                  2.4 13,440 3.1 7,101        1.7
# 33                        0.9 216 1.3 94        0.6
# 34                       1.1 663 1.3 399        0.8
# 35                   4.6 4,888 5.9 2,745        3.3
# 36                   2.2 1,792 2.5 1,047        1.8
# 37                       1.3 571 1.9 202        0.7
# 38                   2.5 2,300 3.2 1,255        1.8
# 39                   2.0 3,010 2.6 1,359        1.3

# %%
#Slice the first seven rows. The second row represents the totals for the county and 
# the rest of the rows are totals for the sub-counties
#the first row doesn't represent anything is specific and hence will be removed.
#However, it will help split the data in it

my_df = df[426].iloc[:8]
my_df
# Out:
#             County / Population 3 Years and above Unnamed: 0 Unnamed: 1  \
# 0         Sub-County           Total* Male Female     Total*   per cent
# 1          KIRINYAGA      571,312 281,556 289,729    137,563       24.1
# 2  KIRINYAGA CENTRAL        114,807 55,919 58,884     32,210       28.1
# 3     KIRINYAGA EAST        127,964 63,267 64,689     28,245       22.1
# 4     KIRINYAGA WEST        107,763 52,630 55,129     26,981       25.0
# 5          MWEA EAST        122,344 60,740 61,598     30,098       24.6
# 6          MWEA WEST         98,400 48,976 49,419     20,009       20.3
# 7   MT. KENYA FOREST                     34 24 10         20       58.8
#
#   Use of Internet Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0   Male per cent     Female   per cent     Total*
# 1     73,577 26.1     63,977       22.1     55,510
# 2     16,912 30.2     15,297       26.0     14,786
# 3     15,600 24.7     12,642       19.5     10,917
# 4     14,332 27.2     12,649       22.9     11,750
# 5     15,721 25.9     14,374       23.3     11,147
# 6     10,996 22.5      9,011       18.2      6,901
# 7         16 66.7          4       40.0          9
#
#   Use of Desktop Computer/Laptop/Tablet Unnamed: 5
# 0         per cent Male per cent Female   per cent
# 1                9.7 30,794 10.9 24,715        8.5
# 2                 12.9 7,974 14.3 6,812       11.6
# 3                   8.5 6,183 9.8 4,734        7.3
# 4                 10.9 6,526 12.4 5,224        9.5
# 5                  9.1 6,141 10.1 5,005        8.1
# 6                   7.0 3,962 8.1 2,939        5.9
# 7                         26.5 8 33.3 1       10.0

# %%
#Check the columns that are present

my_df.columns
# Out:
# Index(['County /', 'Population 3 Years and above', 'Unnamed: 0', 'Unnamed: 1',
#        'Use of Internet', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Use of Desktop Computer/Laptop/Tablet', 'Unnamed: 5'],
#       dtype='object')

# %%
#rename the colums to be understandable

my_df = my_df.rename(columns={"County /": "county/subcounty",
                              "Population 3 Years and above": "pop",
                              "Unnamed: 0":"internet pop",
                              "Unnamed: 1":"internet pop percent",
                              "Unnamed: 2": "female internet pop",
                              "Unnamed: 3": "female internet pop percent",
                              "Unnamed: 4": "pc total pop",
                              "Unnamed: 5": "pc female percent pop",
                             })

# %%
#check if they were renamed correctly

my_df
# Out:
#     county/subcounty                      pop internet pop  \
# 0         Sub-County       Total* Male Female       Total*
# 1          KIRINYAGA  571,312 281,556 289,729      137,563
# 2  KIRINYAGA CENTRAL    114,807 55,919 58,884       32,210
# 3     KIRINYAGA EAST    127,964 63,267 64,689       28,245
# 4     KIRINYAGA WEST    107,763 52,630 55,129       26,981
# 5          MWEA EAST    122,344 60,740 61,598       30,098
# 6          MWEA WEST     98,400 48,976 49,419       20,009
# 7   MT. KENYA FOREST                 34 24 10           20
#
#   internet pop percent Use of Internet female internet pop  \
# 0             per cent   Male per cent              Female
# 1                 24.1     73,577 26.1              63,977
# 2                 28.1     16,912 30.2              15,297
# 3                 22.1     15,600 24.7              12,642
# 4                 25.0     14,332 27.2              12,649
# 5                 24.6     15,721 25.9              14,374
# 6                 20.3     10,996 22.5               9,011
# 7                 58.8         16 66.7                   4
#
#   female internet pop percent pc total pop  \
# 0                    per cent       Total*
# 1                        22.1       55,510
# 2                        26.0       14,786
# 3                        19.5       10,917
# 4                        22.9       11,750
# 5                        23.3       11,147
# 6                        18.2        6,901
# 7                        40.0            9
#
#   Use of Desktop Computer/Laptop/Tablet pc female percent pop
# 0         per cent Male per cent Female              per cent
# 1                9.7 30,794 10.9 24,715                   8.5
# 2                 12.9 7,974 14.3 6,812                  11.6
# 3                   8.5 6,183 9.8 4,734                   7.3
# 4                 10.9 6,526 12.4 5,224                   9.5
# 5                  9.1 6,141 10.1 5,005                   8.1
# 6                   7.0 3,962 8.1 2,939                   5.9
# 7                         26.5 8 33.3 1                  10.0

# %%
#since the first row will be used in spliting, 
#we rename it in such a way that we can use the space in between to separe the data

my_df.iloc[:1, -2:-1] = 'ttl_percent Male male_percent Female'
my_df.iloc[:1, 1:2] = 'Total Male Female'
my_df.iloc[:1,4:5] = 'Male percent'

# %%
#we then split the following columns: a) pop, b) Use of Desktop Computer/Laptop/Tablet, c)Use of Internet
#we define functions that will split the columns

import re
def space_separator(row,row_num):
    """
    row = is the rows in the dataframe
    row_num = is the index of the row
    """
    #clearing  lists
    items = []
    sorted_items = []
    
    #splitting the  row
    items = re.split(' ',row)

    #removing extra spaces and storing in sorted items list
    sorted_items = [item for item in items if item != '']
    
    #setting the list items into columns in the data frame
    my_df.loc[row_num,'total_pc_percent'] = sorted_items[0]
    my_df.loc[row_num,'male_pc_pop'] = sorted_items[1]
    my_df.loc[row_num,'male_pc_percent'] = sorted_items[2]
    my_df.loc[row_num,'female_pc_pop'] = sorted_items[3]
    
    #printing out the sorted row
    print(sorted_items)
    
def space_separator2(row,row_num):
    """
    row = is the rows in the dataframe
    row_num = is the index of the row
    """
    #clearing  lists
    items = []
    sorted_items = []
    
    #splitting the  row
    items = re.split(' ',row)

    #removing extra spaces and storing in sorted items list
    sorted_items = [item for item in items if item != '']
    
    #setting the list items into columns in the data frame
    my_df.loc[row_num,'total_pop'] = sorted_items[0]
    my_df.loc[row_num,'male_Pop'] = sorted_items[1]
    my_df.loc[row_num,'female_Pop'] = sorted_items[2]
    #df_new.loc[row_num,'Female'] = sorted_items[3]
    
    #printing out the sorted row
    print(sorted_items)
    
def space_separator3(row,row_num):
    """
    row = is the rows in the dataframe
    row_num = is the index of the row
    """
    #clearing  lists
    items = []
    sorted_items = []
    
    #splitting the  row
    items = re.split(' ',row)

    #removing extra spaces and storing in sorted items list
    sorted_items = [item for item in items if item != '']
    
    #setting the list items into columns in the data frame
    my_df.loc[row_num,'male internet pop'] = sorted_items[0]
    my_df.loc[row_num,'male internet pop percent'] = sorted_items[1]
    #my_df.loc[row_num,'female_Pop'] = sorted_items[2]
    #df_new.loc[row_num,'Female'] = sorted_items[3]
    
    #printing out the sorted row
    print(sorted_items)

# %%
#iterating through the rows in the dataframe to split the columns

for row_num in range(len(my_df['Use of Desktop Computer/Laptop/Tablet'])):
    space_separator(my_df['Use of Desktop Computer/Laptop/Tablet'][row_num], row_num)
    
for row_num in range(len(my_df['pop'])):
    space_separator2(my_df['pop'][row_num], row_num)
    
for row_num in range(len(my_df['Use of Internet'])):
    space_separator3(my_df['Use of Internet'][row_num], row_num)
# Out:
# ['ttl_percent', 'Male', 'male_percent', 'Female']
# ['9.7', '30,794', '10.9', '24,715']
# ['12.9', '7,974', '14.3', '6,812']
# ['8.5', '6,183', '9.8', '4,734']
# ['10.9', '6,526', '12.4', '5,224']
# ['9.1', '6,141', '10.1', '5,005']
# ['7.0', '3,962', '8.1', '2,939']
# ['26.5', '8', '33.3', '1']
# ['Total', 'Male', 'Female']
# ['571,312', '281,556', '289,729']
# ['114,807', '55,919', '58,884']
# ['127,964', '63,267', '64,689']
# ['107,763', '52,630', '55,129']
# ['122,344', '60,740', '61,598']
# ['98,400', '48,976', '49,419']
# ['34', '24', '10']
# ['Male', 'percent']
# ['73,577', '26.1']
# ['16,912', '30.2']
# ['15,600', '24.7']
# ['14,332', '27.2']
# ['15,721', '25.9']
# ['10,996', '22.5']
# ['16', '66.7']

# %%
#After splitting we get new set of columns hence no need to keep those we used to split
#Also we no loner need the first row and we drop it

df_final = my_df[1:].drop(['pop','Use of Desktop Computer/Laptop/Tablet','Use of Internet'], axis = 1)

# %%
#Checking how the final data looks like

df_final
# Out:
#     county/subcounty internet pop internet pop percent female internet pop  \
# 1          KIRINYAGA      137,563                 24.1              63,977
# 2  KIRINYAGA CENTRAL       32,210                 28.1              15,297
# 3     KIRINYAGA EAST       28,245                 22.1              12,642
# 4     KIRINYAGA WEST       26,981                 25.0              12,649
# 5          MWEA EAST       30,098                 24.6              14,374
# 6          MWEA WEST       20,009                 20.3               9,011
# 7   MT. KENYA FOREST           20                 58.8                   4
#
#   female internet pop percent pc total pop pc female percent pop  \
# 1                        22.1       55,510                   8.5
# 2                        26.0       14,786                  11.6
# 3                        19.5       10,917                   7.3
# 4                        22.9       11,750                   9.5
# 5                        23.3       11,147                   8.1
# 6                        18.2        6,901                   5.9
# 7                        40.0            9                  10.0
#
#   total_pc_percent male_pc_pop male_pc_percent female_pc_pop total_pop  \
# 1              9.7      30,794            10.9        24,715   571,312
# 2             12.9       7,974            14.3         6,812   114,807
# 3              8.5       6,183             9.8         4,734   127,964
# 4             10.9       6,526            12.4         5,224   107,763
# 5              9.1       6,141            10.1         5,005   122,344
# 6              7.0       3,962             8.1         2,939    98,400
# 7             26.5           8            33.3             1        34
#
#   male_Pop female_Pop male internet pop male internet pop percent
# 1  281,556    289,729            73,577                      26.1
# 2   55,919     58,884            16,912                      30.2
# 3   63,267     64,689            15,600                      24.7
# 4   52,630     55,129            14,332                      27.2
# 5   60,740     61,598            15,721                      25.9
# 6   48,976     49,419            10,996                      22.5
# 7       24         10                16                      66.7

# %%
#Export the data to csv

df_final.to_csv('Kirinyaga internet and computer use population.csv')
